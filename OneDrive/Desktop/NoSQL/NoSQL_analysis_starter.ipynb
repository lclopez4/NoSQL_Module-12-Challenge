# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# %pip install pymongo

from pymongo import MongoClient
client = MongoClient("mongodb://localhost:27017/")
print(client.list_database_names())  # Should return a list like ['admin', 'local']
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ['admin', 'config', 'local', 'uk_food']

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
sample_doc = {
    "name": "Green Garden Café",
    "address": "42 Oak Street",
    "rating": 4,
    "cuisine": "Vegetarian"
}

# Insert the document
db['establishments'].insert_one(sample_doc)
# Out:
# InsertOneResult(ObjectId('68361a300043c6e415207562'), acknowledged=True)

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
db.list_collection_names()
# Out:
# ['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
from pprint import pprint

# Assign the establishments collection to a variable
establishments = db['establishments']

# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': {'$eq': 20}}
result = list(establishments.find(query))

# Use count_documents to display the number of documents in the result
print(establishments.count_documents({'scores.Hygiene': {'$eq': 20}}))
# Display the first document in the results using pprint
if result:
	pprint(result[0])
else:
	print("No documents found with a hygiene score of 20.")
# Out:
# 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('683619fd68ff8c55c415f226'),
#  'geocode': {'latitude': '50.769705', 'longitude': '0.27694'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
# ...

# %%
import pandas as pd

# Convert the result to a Pandas DataFrame
hygiene_20_df = pd.DataFrame(result)

# Display the number of rows in the DataFrame
print(f"Number of rows: {len(hygiene_20_df)}")
# Display the first 10 rows of the DataFrame
hygiene_20_df.head(10)
# Out:
# Number of rows: 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  683619fd68ff8c55c415f226   110681                  0
# 1  683619fd68ff8c55c415f5a0   612039                  0
# 2  683619fd68ff8c55c415f8ad   730933                  0
# 3  683619fd68ff8c55c415fa8c   172735                  0
# 4  683619fd68ff8c55c415fa9c   172953                  0
# 5  683619fd68ff8c55c4160445   512854                  0
# 6  683619fd68ff8c55c4160667  1537089                  0
# 7  683619fd68ff8c55c4161b8e   155648                  0
# 8  683619fd68ff8c55c4161fda  1012883                  0
# 9  683619fd68ff8c55c41627e6   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
doc = establishments.find_one()
pprint(doc)
# Out:
# {'_id': ObjectId('683611ff6869da36bd011c0f'),
#  'address': '42 Oak Street',
#  'cuisine': 'Vegetarian',
#  'name': 'Green Garden Café',
#  'rating': 4}

# %%
for doc in establishments.find().limit(10):
    pprint(doc)
# Out:
# {'_id': ObjectId('683611ff6869da36bd011c0f'),
#  'address': '42 Oak Street',
#  'cuisine': 'Vegetarian',
#  'name': 'Green Garden Café',
#  'rating': 4}
# {'AddressLine1': '27 Granville Road',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Lenox House',
#  'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  'ChangesByServerID': 0,
#  'Distance': 4587.440906956158,
#  'FHRSID': 632212,
#  'LocalAuthorityBusinessID': 'PI/000043474',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DS',
#  'RatingDate': '2020-03-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('683619fd68ff8c55c415d40b'),
# ...

# %%
pipeline = [
    {"$project": {"rating": 1, "type": {"$type": "$rating"}}},
    {"$limit": 10}
]

for doc in establishments.aggregate(pipeline):
    pprint(doc)
# Out:
# {'_id': ObjectId('683611ff6869da36bd011c0f'), 'rating': 4, 'type': 'int'}
# {'_id': ObjectId('683619fd68ff8c55c415d40b'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d40c'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d40d'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d40e'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d40f'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d410'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d411'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d412'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d413'), 'type': 'missing'}

# %%
pipeline = [
    {"$project": {"rating": 1, "type": {"$type": "$rating"}}},
    {"$limit": 10}
]

for doc in establishments.aggregate(pipeline):
    pprint(doc)
# Out:
# {'_id': ObjectId('683611ff6869da36bd011c0f'), 'rating': 4, 'type': 'int'}
# {'_id': ObjectId('683619fd68ff8c55c415d40b'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d40c'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d40d'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d40e'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d40f'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d410'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d411'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d412'), 'type': 'missing'}
# {'_id': ObjectId('683619fd68ff8c55c415d413'), 'type': 'missing'}

# %%
query = {"LocalAuthorityName": "City of London Corporation"}

count = establishments.count_documents(query)
print(f"Documents with 'City of London Corporation': {count}")

if count > 0:
    pprint(establishments.find_one(query))
# Out:
# Documents with 'City of London Corporation': 37
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('683619fd68ff8c55c4160c50'),
# ...

# %%
for doc in establishments.find({}, {"LocalAuthorityName": 1, "rating": 1}).limit(20):
    pprint(doc)
# Out:
# {'_id': ObjectId('683611ff6869da36bd011c0f'), 'rating': 4}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('683619fd68ff8c55c415d40b')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('683619fd68ff8c55c415d40c')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('683619fd68ff8c55c415d40d')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('683619fd68ff8c55c415d40e')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('683619fd68ff8c55c415d40f')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('683619fd68ff8c55c415d410')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('683619fd68ff8c55c415d411')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('683619fd68ff8c55c415d412')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('683619fd68ff8c55c415d413')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('683619fd68ff8c55c415d414')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('683619fd68ff8c55c415d415')}
# ...

# %%
#set all RatingValues to decimal, safely handling non-numeric values
establishments.update_many(
	{},
	[{
		'$set': {
			'RatingValue': {
				'$convert': {
					'input': '$RatingValue',
					'to': 'decimal',
					'onError': None,
					'onNull': None
				}
			}
		}
	}]
)
# Out:
# UpdateResult({'n': 39781, 'nModified': 39771, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
#set all empty RatingValues to 0
establishments.update_many({'RatingValue':''}, [ {'$set':{'RatingValue': 0 }}])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
#set all 'AwaitingInspection' Rating Values to None
establishments.update_many({'RatingValue':'AwaitingInspection'}, [ {'$set':{'RatingValue': None }}])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
#set all 'Awaiting Inspection' Rating Values to None
establishments.update_many({'RatingValue':'Awaiting Inspection'}, [ {'$set':{'RatingValue': None }}])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
#set all 'Exempt' Rating Values to None
establishments.update_many({'RatingValue':'Exempt'}, [ {'$set':{'RatingValue': None }}])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
#set all 'AwaitingPublication' Rating Values to None
establishments.update_many({'RatingValue':'AwaitingPublication'}, [ {'$set':{'RatingValue': None }}])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
#set all 'Pass' Rating Values to None
establishments.update_many({'RatingValue':'Pass'}, [ {'$set':{'RatingValue': None }}])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
#testing that 'RatingValue' can now be compared numerically
len(list(establishments.find({'RatingValue': {'$gte': 4}})))
# Out:
# 32154

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'LocalAuthorityName' :{'$regex': "London"},
         'RatingValue': {'$gte': 4}
         }
results = list(establishments.find(query))
# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query))
# Display the first document in the results using pprint
pprint(results[0])
# Out:
# 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': Decimal128('4'),
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('683619fd68ff8c55c4160c50'),
#  'geocode': {'latitude': '51.369321', 'longitude': '0.508551'},
# ...

# %%
# Convert the result to a Pandas DataFrame
london_rating_4_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(f"Number of rows: {len(london_rating_4_df)}")
# Display the first 10 rows of the DataFrame
london_rating_4_df.head(10)
# Out:
# Number of rows: 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  683619fd68ff8c55c4160c50   621707                  0
# 1  683619fd68ff8c55c4160f61  1130836                  0
# 2  683619fd68ff8c55c4161aac   293783                  0
# 3  683619fd68ff8c55c41628b2   294474                  0
# 4  683619fd68ff8c55c41628b3  1315095                  0
# 5  683619fd68ff8c55c4162fba   294900                  0
# 6  683619fe68ff8c55c41650ba   293756                  0
# 7  683619fe68ff8c55c416548a   878523                  0
# 8  683619fe68ff8c55c41654a6   294606                  0
# 9  683619fe68ff8c55c41654a8   293772                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
#find penang flavor's lat and lon
list(establishments.find({'BusinessName':'Penang Flavours'}))
#query for question 3
#list the top 5 restaurants near penang flavours within the degree search parameters, sorted by hygiene score ascending
degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000
query = {'RatingValue': {'$eq': 5},
         'geocode.latitude':{'$gte': (latitude - degree_search), '$lte': (latitude + degree_search)},
         'geocode.longitude':{'$gte': (longitude - degree_search), '$lte': (longitude + degree_search)}
         }
sort =  [('scores.Hygiene', 1)] # for sorting, 1 is ascending, -1 is descending
limit = 5
results = list(establishments.find(query).sort(sort).limit(limit))
pprint(results)
# Out:
# []

# %%
# Convert result to Pandas DataFrame
near_penang_df = pd.DataFrame(results)
near_penang_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# , 'LocalAuthorityName': {'$regex': "London"}
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
match_query = {'$match': {'scores.Hygiene': {'$eq': 0}}}
group_query = {'$group': {'_id': {'LocalAuthorityName': '$LocalAuthorityName'},
                          'count':{'$sum':1}
                          }}
sort_values = {'$sort': {'count': -1}}

pipeline = [match_query, group_query, sort_values]
results = list(establishments.aggregate(pipeline))
results
# Print the number of documents in the result
print(f"Number of documents in result: {establishments.count_documents(query)}")
# Print the first 10 results
pprint(results[0:10])
# Out:
# Number of documents in result: 0
# [{'_id': {'LocalAuthorityName': 'Thanet'}, 'count': 1130},
#  {'_id': {'LocalAuthorityName': 'Greenwich'}, 'count': 882},
#  {'_id': {'LocalAuthorityName': 'Maidstone'}, 'count': 713},
#  {'_id': {'LocalAuthorityName': 'Newham'}, 'count': 711},
#  {'_id': {'LocalAuthorityName': 'Swale'}, 'count': 686},
#  {'_id': {'LocalAuthorityName': 'Chelmsford'}, 'count': 680},
#  {'_id': {'LocalAuthorityName': 'Medway'}, 'count': 672},
#  {'_id': {'LocalAuthorityName': 'Bexley'}, 'count': 607},
#  {'_id': {'LocalAuthorityName': 'Southend-On-Sea'}, 'count': 586},
#  {'_id': {'LocalAuthorityName': 'Tendring'}, 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
hygiene_0_by_authority_df = pd.DataFrame(results)
hygiene_0_by_authority_df
# Display the number of rows in the DataFrame
len(hygiene_0_by_authority_df)
# Display the first 10 rows of the DataFrame
hygiene_0_by_authority_df.head(10)
# Out:
#                                          _id  count
# 0           {'LocalAuthorityName': 'Thanet'}   1130
# 1        {'LocalAuthorityName': 'Greenwich'}    882
# 2        {'LocalAuthorityName': 'Maidstone'}    713
# 3           {'LocalAuthorityName': 'Newham'}    711
# 4            {'LocalAuthorityName': 'Swale'}    686
# 5       {'LocalAuthorityName': 'Chelmsford'}    680
# 6           {'LocalAuthorityName': 'Medway'}    672
# 7           {'LocalAuthorityName': 'Bexley'}    607
# 8  {'LocalAuthorityName': 'Southend-On-Sea'}    586
# 9         {'LocalAuthorityName': 'Tendring'}    542
